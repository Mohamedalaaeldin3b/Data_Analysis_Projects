# %% [markdown]
# # Real Estate Price Prediction Bengaluru Project

# %% [markdown]
# ***

# %%
import pandas as pd
import numpy as np
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, normalize
from sklearn.model_selection import train_test_split, GridSearchCV, ShuffleSplit, cross_val_score

from sklearn.linear_model import LinearRegression, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import pickle

pd.reset_option('max_rows', 'max_columns')
sns.set_theme()
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # EDA

# %%
df = pd.read_csv('/content/drive/MyDrive/Data_Science/Data/bengaluru_house_prices.csv')
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (12791, 9)

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5328
# total_sqft         0
# bath              73
# balcony          605
# price              0
# dtype: int64

# %%
df = df.drop(['area_type', 'availability', 'society', 'balcony'], axis = 'columns')
df.head()
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0   51.00

# %%
df.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
df = df.dropna(axis = 'rows')
df.shape
# Out:
# (12717, 5)

# %%
df.dtypes
# Out:
# location       object
# size           object
# total_sqft     object
# bath          float64
# price         float64
# dtype: object

# %% [markdown]
# ## price

# %%
df['price'] = df['price'] * 100000
# Out:
# <ipython-input-27-01392932297b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'] * 100000

# %% [markdown]
# ## size

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df[['bhk', 'bhk_copy']] = df['size'].str.split(' ', expand = True)
df = df.drop(['size', 'bhk_copy'], axis = 1)
df['bhk'] = df['bhk'].astype('float')
df.head()
# Out:
# <ipython-input-29-244a81e1d79c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['bhk', 'bhk_copy']] = df['size'].str.split(' ', expand = True)
# <ipython-input-29-244a81e1d79c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['bhk', 'bhk_copy']] = df['size'].str.split(' ', expand = True)
#                    location total_sqft  bath       price  bhk
# 0  Electronic City Phase II       1056   2.0   3907000.0  2.0
# 1          Chikka Tirupathi       2600   5.0  12000000.0  4.0
# 2               Uttarahalli       1440   2.0   6200000.0  3.0
# 3        Lingadheeranahalli       1521   3.0   9500000.0  3.0
# 4                  Kothanur       1200   2.0   5100000.0  2.0

# %% [markdown]
# ## bhk

# %%
df['bhk'].describe()
# Out:
# count    12717.000000
# mean         2.815994
# std          1.312744
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          3.000000
# max         43.000000
# Name: bhk, dtype: float64

# %%
df['bhk'].value_counts()
# Out:
# bhk
# 2.0     5244
# 3.0     4630
# 4.0     1376
# 1.0      631
# 5.0      347
# 6.0      221
# 7.0       99
# 8.0       89
# 9.0       54
# 10.0      14
# 11.0       4
# 27.0       1
# 19.0       1
# 16.0       1
# 43.0       1
# 14.0       1
# 12.0       1
# 13.0       1
# 18.0       1
# Name: count, dtype: int64

# %%
df = df[df['bhk'] <= 10]
df['bhk'].unique()
# Out:
# array([ 2.,  4.,  3.,  6.,  1.,  8.,  7.,  5.,  9., 10.])

# %% [markdown]
# ### total_sqft

# %%
df['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def check_float(x):
    try:
        float(x)
        return np.NaN
    except:
        return x

# %%
df['total_sqft'].apply(check_float).unique()
# Out:
# array([nan, '2100 - 2850', '3067 - 8156', '1042 - 1105', '1145 - 1340',
#        '1015 - 1540', '34.46Sq. Meter', '1195 - 1440', '4125Perch',
#        '1120 - 1145', '3090 - 5002', '1160 - 1195', '1000Sq. Meter',
#        '1115 - 1130', '1100Sq. Yards', '520 - 645', '1000 - 1285',
#        '650 - 665', '633 - 666', '5.31Acres', '30Acres', '1445 - 1455',
#        '884 - 1116', '850 - 1093', '716Sq. Meter', '547.34 - 827.31',
#        '580 - 650', '3425 - 3435', '1804 - 2273', '3630 - 3800',
#        '4000 - 5249', '1500Sq. Meter', '142.61Sq. Meter', '1574Sq. Yards',
#        '1250 - 1305', '670 - 980', '1005.03 - 1252.49', '1004 - 1204',
#        '361.33Sq. Yards', '645 - 936', '2710 - 3360', '2830 - 2882',
#        '596 - 804', '1255 - 1863', '1300 - 1405', '117Sq. Yards',
#        '934 - 1437', '980 - 1030', '2249.81 - 4112.19', '1070 - 1315',
#        '3040Sq. Meter', '500Sq. Yards', '2806 - 3019', '613 - 648',
#        '704 - 730', '1210 - 1477', '3369 - 3464', '1125 - 1500',
#        '167Sq. Meter', '1076 - 1199', '381 - 535', '524 - 894',
#        '540 - 670', '315Sq. Yards', '2725 - 3250', '888 - 1290',
#        '660 - 700', '385 - 440', '770 - 841', '3Cents', '188.89Sq. Yards',
#        '1469 - 1766', '204Sq. Meter', '1255 - 1350', '870 - 1080',
#        '45Sq. Yards', '133.3Sq. Yards', '2580 - 2591', '2563 - 2733',
#        '605 - 624', '1349 - 3324', '78.03Sq. Meter', '3300 - 3335',
#        '1180 - 1630', '1365 - 1700', '122Sq. Yards', '84.53Sq. Meter',
#        '2.09Acres', '981 - 1249', '1565 - 1595', '24Guntha',
#        '1270 - 1275', '840 - 1010', '697Sq. Meter', '655 - 742',
#        '1408 - 1455', '942 - 1117', '598 - 958', '1500Cents',
#        '132Sq. Yards', '1010 - 1300', '2Acres', '1450 - 1950',
#        '1100Sq. Meter', '15Acres', '763 - 805', '3307 - 3464',
#        '1.26Acres', '620 - 934', '2462 - 2467', '540 - 740',
#        '3508 - 4201', '4900 - 4940', '755 - 770', '664 - 722',
#        '151.11Sq. Yards', '596 - 861', '615 - 985', '540 - 565',
#        '750 - 800', '1660 - 1805', '1079 - 1183', '2800 - 2870',
#        '1230 - 1290', '943 - 1220', '2041 - 2090', '527 - 639',
#        '1Grounds', '1160 - 1315', '706 - 716', '2940Sq. Yards',
#        '45.06Sq. Meter', '799 - 803', '2470 - 2790', '783 - 943',
#        '4500 - 5540', '1255 - 1375', '610 - 615', '854 - 960',
#        '2650 - 2990', '1.25Acres', '86.72Sq. Meter', '1230 - 1490',
#        '660 - 780', '1150 - 1194', '684 - 810', '1510 - 1670',
#        '1550 - 1590', '1235 - 1410', '38Guntha', '929 - 1078',
#        '2150 - 2225', '1520 - 1759', '629 - 1026', '1215 - 1495',
#        '6Acres', '1140 - 1250', '2400 - 2600', '1052 - 1322',
#        '5666 - 5669', '712 - 938', '1783 - 1878', '120Sq. Yards',
#        '24Sq. Meter', '2528 - 3188', '650 - 760', '1400 - 1421',
#        '4000 - 4450', '142.84Sq. Meter', '300Sq. Yards', '1437 - 1629',
#        '850 - 1060', '1200 - 1470', '1133 - 1384'], dtype=object)

# %%
def to_float(x):
    try:
        return float(x)
    except:
        if '-' in x:
            tokens = x.split('-')
            return (float(tokens[0]) + float(tokens[1])) / 2
        elif '-' not in x:
            return None

# %%
df['total_sqft'] = df['total_sqft'].apply(to_float)

# %%
df.isnull().sum()
# Out:
# location       0
# total_sqft    46
# bath           0
# price          0
# bhk            0
# dtype: int64

# %%
df = df.dropna(axis = 'rows')

# %%
df['total_sqft'].dtype
# Out:
# dtype('float64')

# %%
df['total_sqft'].describe()
# Out:
# count    12659.000000
# mean      1563.014765
# std       1254.429805
# min          1.000000
# 25%       1100.000000
# 50%       1280.000000
# 75%       1685.000000
# max      52272.000000
# Name: total_sqft, dtype: float64

# %% [markdown]
# ### location

# %%
df['location'].value_counts()
# Out:
# location
# Whitefield                            515
# Sarjapur  Road                        372
# Electronic City                       287
# Kanakpura Road                        240
# Thanisandra                           227
#                                      ...
# Rajanna Layout                          1
# Lakshmipura Vidyaanyapura               1
# Malur Hosur Road                        1
# Kengeri Satellite Town ( BDA SITE)      1
# Abshot Layout                           1
# Name: count, Length: 1289, dtype: int64

# %%
locations = pd.DataFrame(df['location'].value_counts()).reset_index()
locations = locations.rename(columns = {'count': 'location_count'})
locations = locations[locations['location_count'] < 10]
locations
# Out:
#                                 location  location_count
# 249                            Medahalli               9
# 250                              Ejipura               9
# 251                    Jakkur Plantation               9
# 252                       Banagiri Nagar               9
# 253                  Sector 1 HSR Layout               9
# ...                                  ...             ...
# 1284                      Rajanna Layout               1
# 1285           Lakshmipura Vidyaanyapura               1
# 1286                    Malur Hosur Road               1
# 1287  Kengeri Satellite Town ( BDA SITE)               1
# 1288                       Abshot Layout               1
#
# [1040 rows x 2 columns]

# %%
df['location'] = df['location'].apply(
    lambda x: 'Other' if x in list(locations['location']) else x
)
df['location'].value_counts()
# Out:
# location
# Other                   2755
# Whitefield               515
# Sarjapur  Road           372
# Electronic City          287
# Kanakpura Road           240
#                         ...
# Narayanapura              10
# BTM 1st Stage             10
# Nagappa Reddy Layout      10
# Naganathapura             10
# Nagadevanahalli           10
# Name: count, Length: 250, dtype: int64

# %% [markdown]
# # Outliers

# %% [markdown]
# ## price & total_sqft

# %%
df['price'].describe()
# Out:
# count    1.265900e+04
# mean     1.138517e+07
# std      1.515860e+07
# min      8.000000e+05
# 25%      5.000000e+06
# 50%      7.260000e+06
# 75%      1.200000e+07
# max      3.600000e+08
# Name: price, dtype: float64

# %%
df['total_sqft'].describe()
# Out:
# count    12659.000000
# mean      1563.014765
# std       1254.429805
# min          1.000000
# 25%       1100.000000
# 50%       1280.000000
# 75%       1685.000000
# max      52272.000000
# Name: total_sqft, dtype: float64

# %%
plt.figure(figsize = (5,4))
plt.scatter(df['total_sqft'], df['price'], edgecolor = 'k')
plt.xlabel('total sqft')
plt.ylabel('price')
plt.title('Total Sqft v Price', color = 'blue')
plt.show()

# %%
df['price_per_sqft'] = df['price'] / df['total_sqft']
df['price_per_sqft'].describe()
# Out:
# count    1.265900e+04
# mean     8.033790e+03
# std      1.089811e+05
# min      2.678298e+02
# 25%      4.298610e+03
# 50%      5.483631e+03
# 75%      7.400532e+03
# max      1.200000e+07
# Name: price_per_sqft, dtype: float64

# %%
df = df[np.logical_and(df['price_per_sqft'] > 4000, df['price_per_sqft'] < 7000)]

# %%
df.shape
# Out:
# (6641, 6)

# %%
df['total_sqft'].max()
# Out:
# 30400.0

# %%
# try using linear regression with only total_sqft feature after removing outliers

X = df[['total_sqft']]
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 7)
test_model = LinearRegression().fit(X_train, y_train)
test_model.score(X_train, y_train), test_model.score(X_test, y_test)
# Out:
# (0.9261244552746005, 0.8975760099797575)

# %%
k = np.linspace(0, 30000, 1000)
z = test_model.coef_ * k - test_model.intercept_

plt.figure(figsize = (5,4))
plt.scatter(df['total_sqft'], df['price'], edgecolor = 'k')
plt.plot(k, z, color = 'r')
plt.xlabel('total sqft')
plt.ylabel('price')
plt.title('Linear Regression Model', color = 'blue')
plt.show()

# %% [markdown]
# ## sqft_per_bhk

# %%
plt.figure(figsize = (5,4))
plt.scatter(df['bhk'], df['total_sqft'], edgecolor = 'k')
plt.xlabel('bhk')
plt.ylabel('total_sqft')
plt.title('BHK v Total Sqft', color = 'blue')
plt.show()

# %%
df['sqft_per_bhk'] = df['total_sqft'] / df['bhk']
df['sqft_per_bhk'].describe()
# Out:
# count    6641.000000
# mean      570.410616
# std       171.205012
# min       130.888889
# 25%       497.500000
# 50%       556.500000
# 75%       617.500000
# max      6000.000000
# Name: sqft_per_bhk, dtype: float64

# %%
df = df[np.logical_and(df['sqft_per_bhk'] > 200, df['sqft_per_bhk'] < 1000)]

# %%
df.shape
# Out:
# (6528, 7)

# %%
# visualize bhk v total_sqft after removing outliers

plt.figure(figsize = (5,4))
plt.scatter(df['bhk'], df['total_sqft'], edgecolor = 'k')
plt.xlabel('bhk')
plt.ylabel('total_sqft')
plt.title('BHK v Total Sqft', color = 'blue')
plt.show()

# %% [markdown]
# ### bath & bhk

# %%
df['bath_bhk'] = df['bath'] - df['bhk']

# %%
len(df[df['bath_bhk'] > 1])
# Out:
# 36

# %%
df = df[df['bath_bhk'] <= 1]

# %%
df.head()
# Out:
#              location  total_sqft  bath       price  bhk  price_per_sqft  \
# 1    Chikka Tirupathi      2600.0   5.0  12000000.0  4.0     4615.384615
# 2         Uttarahalli      1440.0   2.0   6200000.0  3.0     4305.555556
# 3  Lingadheeranahalli      1521.0   3.0   9500000.0  3.0     6245.890861
# 4            Kothanur      1200.0   2.0   5100000.0  2.0     4250.000000
# 8        Marathahalli      1310.0   3.0   6325000.0  3.0     4828.244275
#
#    sqft_per_bhk  bath_bhk
# 1    650.000000       1.0
# 2    480.000000      -1.0
# 3    507.000000       0.0
# 4    600.000000       0.0
# 8    436.666667       0.0

# %%
df = df.drop(columns = ['sqft_per_bhk', 'price_per_sqft', 'bath_bhk'])

# %%
df
# Out:
#                     location  total_sqft  bath       price  bhk
# 1           Chikka Tirupathi      2600.0   5.0  12000000.0  4.0
# 2                Uttarahalli      1440.0   2.0   6200000.0  3.0
# 3         Lingadheeranahalli      1521.0   3.0   9500000.0  3.0
# 4                   Kothanur      1200.0   2.0   5100000.0  2.0
# 8               Marathahalli      1310.0   3.0   6325000.0  3.0
# ...                      ...         ...   ...         ...  ...
# 13309           Yeshwanthpur      1675.0   3.0   9213000.0  3.0
# 13310           Rachenahalli      1050.0   2.0   5271000.0  2.0
# 13314      Green Glen Layout      1715.0   3.0  11200000.0  3.0
# 13315             Whitefield      3453.0   4.0  23100000.0  5.0
# 13317  Raja Rajeshwari Nagar      1141.0   2.0   6000000.0  2.0
#
# [6492 rows x 5 columns]

# %% [markdown]
# ## location (One Hot Encoding)

# %%
loc_dummies = pd.get_dummies(df.location)
loc_dummies.head()
# Out:
#     Devarachikkanahalli  1st Block Jayanagar  1st Block Koramangala  \
# 1                 False                False                  False
# 2                 False                False                  False
# 3                 False                False                  False
# 4                 False                False                  False
# 8                 False                False                  False
#
#    1st Phase JP Nagar  2nd Stage Nagarbhavi  5th Block Hbr Layout  \
# 1               False                 False                 False
# 2               False                 False                 False
# 3               False                 False                 False
# 4               False                 False                 False
# 8               False                 False                 False
#
#    5th Phase JP Nagar  6th Phase JP Nagar  7th Phase JP Nagar  \
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
# 8               False               False               False
#
#    8th Phase JP Nagar  ...  Vijayanagar  Vishveshwarya Layout  \
# 1               False  ...        False                 False
# 2               False  ...        False                 False
# 3               False  ...        False                 False
# 4               False  ...        False                 False
# 8               False  ...        False                 False
#
#    Vishwapriya Layout  Vittasandra  Whitefield  Yelachenahalli  Yelahanka  \
# 1               False        False       False           False      False
# 2               False        False       False           False      False
# 3               False        False       False           False      False
# 4               False        False       False           False      False
# 8               False        False       False           False      False
#
#    Yelahanka New Town  Yelenahalli  Yeshwanthpur
# 1               False        False         False
# 2               False        False         False
# 3               False        False         False
# 4               False        False         False
# 8               False        False         False
#
# [5 rows x 242 columns]

# %%
loc_dummies = loc_dummies.drop('Other', axis = 'columns')
loc_dummies.head()
# Out:
#     Devarachikkanahalli  1st Block Jayanagar  1st Block Koramangala  \
# 1                 False                False                  False
# 2                 False                False                  False
# 3                 False                False                  False
# 4                 False                False                  False
# 8                 False                False                  False
#
#    1st Phase JP Nagar  2nd Stage Nagarbhavi  5th Block Hbr Layout  \
# 1               False                 False                 False
# 2               False                 False                 False
# 3               False                 False                 False
# 4               False                 False                 False
# 8               False                 False                 False
#
#    5th Phase JP Nagar  6th Phase JP Nagar  7th Phase JP Nagar  \
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
# 8               False               False               False
#
#    8th Phase JP Nagar  ...  Vijayanagar  Vishveshwarya Layout  \
# 1               False  ...        False                 False
# 2               False  ...        False                 False
# 3               False  ...        False                 False
# 4               False  ...        False                 False
# 8               False  ...        False                 False
#
#    Vishwapriya Layout  Vittasandra  Whitefield  Yelachenahalli  Yelahanka  \
# 1               False        False       False           False      False
# 2               False        False       False           False      False
# 3               False        False       False           False      False
# 4               False        False       False           False      False
# 8               False        False       False           False      False
#
#    Yelahanka New Town  Yelenahalli  Yeshwanthpur
# 1               False        False         False
# 2               False        False         False
# 3               False        False         False
# 4               False        False         False
# 8               False        False         False
#
# [5 rows x 241 columns]

# %%
df = pd.concat([df, loc_dummies], axis = 'columns')
df.head()
# Out:
#              location  total_sqft  bath       price  bhk  \
# 1    Chikka Tirupathi      2600.0   5.0  12000000.0  4.0
# 2         Uttarahalli      1440.0   2.0   6200000.0  3.0
# 3  Lingadheeranahalli      1521.0   3.0   9500000.0  3.0
# 4            Kothanur      1200.0   2.0   5100000.0  2.0
# 8        Marathahalli      1310.0   3.0   6325000.0  3.0
#
#     Devarachikkanahalli  1st Block Jayanagar  1st Block Koramangala  \
# 1                 False                False                  False
# 2                 False                False                  False
# 3                 False                False                  False
# 4                 False                False                  False
# 8                 False                False                  False
#
#    1st Phase JP Nagar  2nd Stage Nagarbhavi  ...  Vijayanagar  \
# 1               False                 False  ...        False
# 2               False                 False  ...        False
# 3               False                 False  ...        False
# 4               False                 False  ...        False
# 8               False                 False  ...        False
#
#    Vishveshwarya Layout  Vishwapriya Layout  Vittasandra  Whitefield  \
# 1                 False               False        False       False
# 2                 False               False        False       False
# 3                 False               False        False       False
# 4                 False               False        False       False
# 8                 False               False        False       False
#
#    Yelachenahalli  Yelahanka  Yelahanka New Town  Yelenahalli  Yeshwanthpur
# 1           False      False               False        False         False
# 2           False      False               False        False         False
# 3           False      False               False        False         False
# 4           False      False               False        False         False
# 8           False      False               False        False         False
#
# [5 rows x 246 columns]

# %%
df = df.drop('location', axis = 'columns')
df.head()
# Out:
#    total_sqft  bath       price  bhk   Devarachikkanahalli  \
# 1      2600.0   5.0  12000000.0  4.0                 False
# 2      1440.0   2.0   6200000.0  3.0                 False
# 3      1521.0   3.0   9500000.0  3.0                 False
# 4      1200.0   2.0   5100000.0  2.0                 False
# 8      1310.0   3.0   6325000.0  3.0                 False
#
#    1st Block Jayanagar  1st Block Koramangala  1st Phase JP Nagar  \
# 1                False                  False               False
# 2                False                  False               False
# 3                False                  False               False
# 4                False                  False               False
# 8                False                  False               False
#
#    2nd Stage Nagarbhavi  5th Block Hbr Layout  ...  Vijayanagar  \
# 1                 False                 False  ...        False
# 2                 False                 False  ...        False
# 3                 False                 False  ...        False
# 4                 False                 False  ...        False
# 8                 False                 False  ...        False
#
#    Vishveshwarya Layout  Vishwapriya Layout  Vittasandra  Whitefield  \
# 1                 False               False        False       False
# 2                 False               False        False       False
# 3                 False               False        False       False
# 4                 False               False        False       False
# 8                 False               False        False       False
#
#    Yelachenahalli  Yelahanka  Yelahanka New Town  Yelenahalli  Yeshwanthpur
# 1           False      False               False        False         False
# 2           False      False               False        False         False
# 3           False      False               False        False         False
# 4           False      False               False        False         False
# 8           False      False               False        False         False
#
# [5 rows x 245 columns]

# %%
df = df.reset_index(drop = True)
df
# Out:
#       total_sqft  bath       price  bhk   Devarachikkanahalli  \
# 0         2600.0   5.0  12000000.0  4.0                 False
# 1         1440.0   2.0   6200000.0  3.0                 False
# 2         1521.0   3.0   9500000.0  3.0                 False
# 3         1200.0   2.0   5100000.0  2.0                 False
# 4         1310.0   3.0   6325000.0  3.0                 False
# ...          ...   ...         ...  ...                   ...
# 6487      1675.0   3.0   9213000.0  3.0                 False
# 6488      1050.0   2.0   5271000.0  2.0                 False
# 6489      1715.0   3.0  11200000.0  3.0                 False
# 6490      3453.0   4.0  23100000.0  5.0                 False
# 6491      1141.0   2.0   6000000.0  2.0                 False
#
#       1st Block Jayanagar  1st Block Koramangala  1st Phase JP Nagar  \
# 0                   False                  False               False
# 1                   False                  False               False
# 2                   False                  False               False
# 3                   False                  False               False
# 4                   False                  False               False
# ...                   ...                    ...                 ...
# 6487                False                  False               False
# 6488                False                  False               False
# 6489                False                  False               False
# 6490                False                  False               False
# 6491                False                  False               False
#
#       2nd Stage Nagarbhavi  5th Block Hbr Layout  ...  Vijayanagar  \
# 0                    False                 False  ...        False
# 1                    False                 False  ...        False
# 2                    False                 False  ...        False
# 3                    False                 False  ...        False
# 4                    False                 False  ...        False
# ...                    ...                   ...  ...          ...
# 6487                 False                 False  ...        False
# 6488                 False                 False  ...        False
# 6489                 False                 False  ...        False
# 6490                 False                 False  ...        False
# 6491                 False                 False  ...        False
#
#       Vishveshwarya Layout  Vishwapriya Layout  Vittasandra  Whitefield  \
# 0                    False               False        False       False
# 1                    False               False        False       False
# 2                    False               False        False       False
# 3                    False               False        False       False
# 4                    False               False        False       False
# ...                    ...                 ...          ...         ...
# 6487                 False               False        False       False
# 6488                 False               False        False       False
# 6489                 False               False        False       False
# 6490                 False               False        False        True
# 6491                 False               False        False       False
#
#       Yelachenahalli  Yelahanka  Yelahanka New Town  Yelenahalli  Yeshwanthpur
# 0              False      False               False        False         False
# 1              False      False               False        False         False
# 2              False      False               False        False         False
# 3              False      False               False        False         False
# 4              False      False               False        False         False
# ...              ...        ...                 ...          ...           ...
# 6487           False      False               False        False          True
# 6488           False      False               False        False         False
# 6489           False      False               False        False         False
# 6490           False      False               False        False         False
# 6491           False      False               False        False         False
#
# [6492 rows x 245 columns]

# %% [markdown]
# # Model Building

# %%
X = df.drop(columns = ['price'])
X
# Out:
#       total_sqft  bath  bhk   Devarachikkanahalli  1st Block Jayanagar  \
# 0         2600.0   5.0  4.0                 False                False
# 1         1440.0   2.0  3.0                 False                False
# 2         1521.0   3.0  3.0                 False                False
# 3         1200.0   2.0  2.0                 False                False
# 4         1310.0   3.0  3.0                 False                False
# ...          ...   ...  ...                   ...                  ...
# 6487      1675.0   3.0  3.0                 False                False
# 6488      1050.0   2.0  2.0                 False                False
# 6489      1715.0   3.0  3.0                 False                False
# 6490      3453.0   4.0  5.0                 False                False
# 6491      1141.0   2.0  2.0                 False                False
#
#       1st Block Koramangala  1st Phase JP Nagar  2nd Stage Nagarbhavi  \
# 0                     False               False                 False
# 1                     False               False                 False
# 2                     False               False                 False
# 3                     False               False                 False
# 4                     False               False                 False
# ...                     ...                 ...                   ...
# 6487                  False               False                 False
# 6488                  False               False                 False
# 6489                  False               False                 False
# 6490                  False               False                 False
# 6491                  False               False                 False
#
#       5th Block Hbr Layout  5th Phase JP Nagar  ...  Vijayanagar  \
# 0                    False               False  ...        False
# 1                    False               False  ...        False
# 2                    False               False  ...        False
# 3                    False               False  ...        False
# 4                    False               False  ...        False
# ...                    ...                 ...  ...          ...
# 6487                 False               False  ...        False
# 6488                 False               False  ...        False
# 6489                 False               False  ...        False
# 6490                 False               False  ...        False
# 6491                 False               False  ...        False
#
#       Vishveshwarya Layout  Vishwapriya Layout  Vittasandra  Whitefield  \
# 0                    False               False        False       False
# 1                    False               False        False       False
# 2                    False               False        False       False
# 3                    False               False        False       False
# 4                    False               False        False       False
# ...                    ...                 ...          ...         ...
# 6487                 False               False        False       False
# 6488                 False               False        False       False
# 6489                 False               False        False       False
# 6490                 False               False        False        True
# 6491                 False               False        False       False
#
#       Yelachenahalli  Yelahanka  Yelahanka New Town  Yelenahalli  Yeshwanthpur
# 0              False      False               False        False         False
# 1              False      False               False        False         False
# 2              False      False               False        False         False
# 3              False      False               False        False         False
# 4              False      False               False        False         False
# ...              ...        ...                 ...          ...           ...
# 6487           False      False               False        False          True
# 6488           False      False               False        False         False
# 6489           False      False               False        False         False
# 6490           False      False               False        False         False
# 6491           False      False               False        False         False
#
# [6492 rows x 244 columns]

# %%
y = df['price']
y
# Out:
# 0       12000000.0
# 1        6200000.0
# 2        9500000.0
# 3        5100000.0
# 4        6325000.0
#            ...
# 6487     9213000.0
# 6488     5271000.0
# 6489    11200000.0
# 6490    23100000.0
# 6491     6000000.0
# Name: price, Length: 6492, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 7)

# %%
X_train
# Out:
#       total_sqft  bath  bhk   Devarachikkanahalli  1st Block Jayanagar  \
# 2738      1440.0   4.0  4.0                 False                False
# 1715      1460.0   2.0  3.0                 False                False
# 5249      2100.0   3.0  3.0                 False                False
# 5309      1250.0   2.0  2.0                 False                False
# 188       1000.0   2.0  2.0                 False                False
# ...          ...   ...  ...                   ...                  ...
# 5699      1718.0   3.0  3.0                 False                False
# 2550      1486.0   3.0  3.0                 False                False
# 537       1100.0   3.0  3.0                 False                False
# 1220      1220.0   3.0  3.0                 False                False
# 4271      1250.0   2.0  2.0                 False                False
#
#       1st Block Koramangala  1st Phase JP Nagar  2nd Stage Nagarbhavi  \
# 2738                  False               False                 False
# 1715                  False               False                 False
# 5249                  False               False                 False
# 5309                  False               False                 False
# 188                   False               False                 False
# ...                     ...                 ...                   ...
# 5699                  False               False                 False
# 2550                  False               False                 False
# 537                   False               False                 False
# 1220                  False               False                 False
# 4271                  False               False                 False
#
#       5th Block Hbr Layout  5th Phase JP Nagar  ...  Vijayanagar  \
# 2738                 False               False  ...        False
# 1715                 False               False  ...        False
# 5249                 False               False  ...        False
# 5309                 False               False  ...        False
# 188                  False               False  ...        False
# ...                    ...                 ...  ...          ...
# 5699                 False               False  ...        False
# 2550                 False               False  ...        False
# 537                  False               False  ...        False
# 1220                 False               False  ...        False
# 4271                 False               False  ...        False
#
#       Vishveshwarya Layout  Vishwapriya Layout  Vittasandra  Whitefield  \
# 2738                 False               False        False       False
# 1715                 False               False        False       False
# 5249                 False               False        False       False
# 5309                 False               False        False       False
# 188                  False               False        False       False
# ...                    ...                 ...          ...         ...
# 5699                 False               False        False       False
# 2550                 False               False        False       False
# 537                  False               False        False       False
# 1220                 False               False        False       False
# 4271                 False               False        False       False
#
#       Yelachenahalli  Yelahanka  Yelahanka New Town  Yelenahalli  Yeshwanthpur
# 2738           False      False               False        False         False
# 1715           False      False               False        False         False
# 5249           False      False               False        False         False
# 5309           False      False               False        False         False
# 188            False      False               False        False         False
# ...              ...        ...                 ...          ...           ...
# 5699           False      False               False        False         False
# 2550           False      False               False        False         False
# 537            False      False               False        False         False
# 1220           False      False               False        False         False
# 4271           False      False               False        False         False
#
# [5193 rows x 244 columns]

# %%
y_train
# Out:
# 2738     8800000.0
# 1715     7300000.0
# 5249    12500000.0
# 5309     6200000.0
# 188      6700000.0
#            ...
# 5699     9020000.0
# 2550     8322000.0
# 537      5300000.0
# 1220     5600000.0
# 4271     7500000.0
# Name: price, Length: 5193, dtype: float64

# %%
cv = ShuffleSplit(n_splits = 5, test_size = 0.2, random_state = 7)

# %% [markdown]
# ## LinearRegression

# %%
linear_reg_model = LinearRegression().fit(X_train, y_train)
linear_reg_model.score(X_train, y_train), linear_reg_model.score(X_test, y_test)
# Out:
# (0.8856698375498739, 0.8612659863569714)

# %%
cross_val_score(LinearRegression(), X, y, cv = cv)
# Out:
# array([0.86126599, 0.88150525, 0.8736491 , 0.84369509, 0.87898502])

# %% [markdown]
# ## XGBRegressor

# %%
xgboost_model = XGBRegressor().fit(X_train, y_train)
xgboost_model.score(X_train, y_train), xgboost_model.score(X_test, y_test)
# Out:
# (0.9248894982596321, 0.8597593880896082)

# %%
cross_val_score(XGBRegressor(), X, y, cv = cv)
# Out:
# array([0.85975939, 0.88210825, 0.88571425, 0.84227666, 0.88502554])

# %% [markdown]
# ## Lasso

# %%
lasso_model = Lasso().fit(X_train, y_train)
lasso_model.score(X_train, y_train), lasso_model.score(X_test, y_test)
# Out:
# (0.885669813700728, 0.8612769167412465)

# %%
cross_val_score(Lasso(), X, y, cv = cv)
# Out:
# array([0.86127692, 0.88151214, 0.87365711, 0.84369798, 0.87899583])

# %% [markdown]
# ## DecisionTreeRegressor

# %%
decision_tree_model = DecisionTreeRegressor().fit(X_train, y_train)
decision_tree_model.score(X_train, y_train), decision_tree_model.score(X_test, y_test)
# Out:
# (0.9861472058928629, 0.7991655952543565)

# %%
cross_val_score(DecisionTreeRegressor(), X, y, cv = cv)
# Out:
# array([0.80568255, 0.82562862, 0.84296634, 0.75924439, 0.8175319 ])

# %% [markdown]
# ## RandomForestRegressor

# %%
random_forest_model = RandomForestRegressor().fit(X_train, y_train)
random_forest_model.score(X_train, y_train), random_forest_model.score(X_test, y_test)
# Out:
# (0.9711582385755683, 0.8567435133903192)

# %%
cross_val_score(RandomForestRegressor(), X, y, cv = cv)
# Out:
# array([0.8545316 , 0.87916004, 0.87677477, 0.8342051 , 0.87364982])

# %% [markdown]
# # Choosing Best Model

# %%
pd.DataFrame(
    {
        'train|test':           ['train', 'test'],
        'Linear Regression':    [linear_reg_model.score(X_train, y_train), linear_reg_model.score(X_test, y_test)],
        'XGBoost':              [xgboost_model.score(X_train, y_train), xgboost_model.score(X_test, y_test)],
        'Lasso':                [lasso_model.score(X_train, y_train), lasso_model.score(X_test, y_test)],
        'Decision Tree':        [decision_tree_model.score(X_train, y_train), decision_tree_model.score(X_test, y_test)],
        'Random Forest':        [random_forest_model.score(X_train, y_train), random_forest_model.score(X_test, y_test)]
    }
)
# Out:
#   train|test  Linear Regression   XGBoost     Lasso  Decision Tree  \
# 0      train           0.885670  0.924889  0.885670       0.986147
# 1       test           0.861266  0.859759  0.861277       0.799166
#
#    Random Forest
# 0       0.971158
# 1       0.856744

# %%
# choosing Linear Regression Model

import pickle
with open('Real_Estate_Price_Prediction_Bengaluru_Project.pickle','wb') as f:
    pickle.dump(linear_reg_model, f)

# %% [markdown]
# ***

# %% [markdown]
# **End of Project**
